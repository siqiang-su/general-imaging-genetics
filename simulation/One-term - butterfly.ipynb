# %%
# %load_ext autoreload
# %autoreload 1
# %aimport Joint_Generation,utils,Alternating_Minimization

import numpy as np
from matplotlib import pyplot as plt
from skimage.transform import resize
import random
from utils import *
from Joint_Generation import *
from Alternating_Minimization import *
import math
import scipy
import scipy.linalg
import scipy.stats
from sklearn.linear_model import LinearRegression, Lasso

# %%
# Dimension settings
p = 100
D1 = 32
D2 = 32
N = 1000
p1 = 16
p2 = 16
d1 = 2
d2 = 2
mux = np.zeros((p))
muy = np.zeros((D1*D2))

# %%
C_true = np.load('butterfly_32x32.npy')
C_vec = C_true.reshape(D1*D2,1)
plt.imshow(C_true,cmap="gray")

# %%
nsim = 10
tpr_theta = np.zeros(nsim)
fpr_theta = np.zeros(nsim)
tpr_C = np.zeros(nsim)
fpr_C = np.zeros(nsim)
err_c = np.zeros(nsim)
err_theta = np.zeros(nsim)
for i in range(nsim):
    X,Y,Yarray,theta,z,indx = data_generation(N=N,rho1=0.8,rho2=0.6,p=100,D1=D1,D2=D2,mux=mux,muy=muy,C_vec=C_vec,C_true=C_true,type="identity",verbose=False)
    a,b,thetahat = cca_alt_minimization(N,X,Yarray,z,lam1=0.0002,lam2=0.0003,R=1,tau_x=0.01,tau_y=0.01,p1=p1,p2=p2,d1=d1,d2=d2,p=p,niter=5,init='uniform')
    TPR_theta, FPR_theta, theta_err, TPR_C, FPR_C, C_err, C_hat, canoncor, zXcor, zYcor, sumcor = cca_sim_evaluation(N,X,Yarray,z,a=a,b=b,R=1,theta=theta,C_true=C_true,thetahat=thetahat,indx=indx,p1=p1,p2=p2,d1=d1,d2=d2,D1=D1,D2=D2,show=True)
    tpr_theta[i] = TPR_theta
    fpr_theta[i] = FPR_theta
    tpr_C[i] = TPR_C
    fpr_C[i] = FPR_C
    err_c[i] = C_err
    err_theta[i] = theta_err
print('Mean TPR for C is: ',np.mean(tpr_C))
print('Mean FPR for C is: ',np.mean(fpr_C))
print('Mean TPR for theta is: ',np.mean(tpr_theta))
print('Mean FPR for theta is: ',np.mean(fpr_theta))
print('Mean MSE for C is: ',np.mean(err_c))
print('Mean MSE for theta is: ',np.mean(err_theta))
# Out:
# TPR of theta is:  1.0
# FPR of theta is:  0.021052631578947368
# TPR of C is:  0.9508196721311475
# FPR of C is:  0.014537902388369679
# TPR of theta is:  0.8
# FPR of theta is:  0.021052631578947368
# TPR of C is:  0.9180327868852459
# FPR of C is:  0.012461059190031152
# TPR of theta is:  1.0
# FPR of theta is:  0.031578947368421054
# TPR of C is:  0.9180327868852459
# FPR of C is:  0.016614745586708203
# TPR of theta is:  1.0
# FPR of theta is:  0.042105263157894736
# TPR of C is:  0.9508196721311475
# FPR of C is:  0.010384215991692628
# TPR of theta is:  1.0
# FPR of theta is:  0.021052631578947368
# TPR of C is:  0.9180327868852459
# FPR of C is:  0.012461059190031152
# TPR of theta is:  1.0
# FPR of theta is:  0.021052631578947368
# TPR of C is:  0.9508196721311475
# FPR of C is:  0.006230529595015576
# TPR of theta is:  1.0
# FPR of theta is:  0.06315789473684211
# TPR of C is:  0.9672131147540983
# FPR of C is:  0.013499480789200415
# TPR of theta is:  0.8
# FPR of theta is:  0.021052631578947368
# TPR of C is:  0.9508196721311475
# FPR of C is:  0.014537902388369679
# TPR of theta is:  1.0
# FPR of theta is:  0.031578947368421054
# TPR of C is:  0.9180327868852459
# FPR of C is:  0.004153686396677051
# TPR of theta is:  0.8
# FPR of theta is:  0.021052631578947368
# TPR of C is:  0.9180327868852459
# FPR of C is:  0.016614745586708203
# Mean TPR for C is:  0.9360655737704917
# Mean FPR for C is:  0.012149532710280376
# Mean TPR for theta is:  0.9400000000000001
# Mean FPR for theta is:  0.02947368421052632
# Mean MSE for C is:  0.1737723797316604
# Mean MSE for theta is:  0.31554234819735993

# %%
# %reset
